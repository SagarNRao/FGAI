# %%
# %pip install langchain langchain-google-genai python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

# =============================================
# HARDCODED Gemini API key – ONLY for local testing!
# NEVER commit or share this code
# =============================================
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",              # or "gemini-1.5-pro", "gemini-2.0-flash", etc.
    google_api_key="AIzaSyBnHcPi81zPIs4XKKvkFxH_-yvXgwzBXSc",   # ← REPLACE WITH YOUR ACTUAL KEY
    temperature=0.7,
    max_output_tokens=1200,
)

# ───────────────────────────────────────────────
# Quick test – single prompt
# ───────────────────────────────────────────────
response = llm.invoke("Say hello in pirate speak")
print(response.content)


# ───────────────────────────────────────────────
# Better: using a prompt template
# ───────────────────────────────────────────────
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a cheerful {role} who always answers in a fun way."),
    ("human", "{question}"),
])

chain = prompt | llm

response = chain.invoke({
    "role": "math wizard",
    "question": "What's 17 × 42?"
})

print(response.content)


# ───────────────────────────────────────────────
# Another quick example – few-shot style
# ───────────────────────────────────────────────
prompt_fun = ChatPromptTemplate.from_messages([
    ("system", "You answer everything like a dramatic movie trailer voice."),
    ("human", "Tell me about coffee."),
    ("ai", "In a world… where mornings are dark and silent… one bean rises to awaken the soul…"),
    ("human", "{question}"),
])

chain_fun = prompt_fun | llm

print(
    chain_fun.invoke({"question": "Tell me about Python programming"}).content
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Python312\Lib\site-packages\langchain_google_genai\chat_models.py:3047, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3046 try:
# -> 3047     response: GenerateContentResponse = self.client.models.generate_content(
#    3048         **request,
#    3049     )
#    3050 except ClientError as e:
#
# File c:\Python312\Lib\site-packages\google\genai\models.py:5215, in Models.generate_content(self, model, contents, config)
#    5214 i += 1
# -> 5215 response = self._generate_content(
#    5216     model=model, contents=contents, config=parsed_config
#    5217 )
#    5219 function_map = _extra_utils.get_function_map(parsed_config)
#
# ...
